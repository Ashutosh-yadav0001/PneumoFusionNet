# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/annotation.json
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/metadata.jsonl
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/metadata_2im_label.jsonl
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3535_IM-1728-0001/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3535_IM-1728-0001/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1668_IM-0441/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1668_IM-0441/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3829_IM-1932/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3829_IM-1932/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2861_IM-1269/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2861_IM-1269/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2288_IM-0872/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2288_IM-0872/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1640_IM-0420/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1640_IM-0420/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1993_IM-0650/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1993_IM-0650/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1415_IM-0264/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1415_IM-0264/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1174_IM-0118/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1174_IM-0118/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1770_IM-0504/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1770_IM-0504/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3527_IM-1724/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3527_IM-1724/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3194_IM-1505/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3194_IM-1505/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2578_IM-1078/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2578_IM-1078/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2829_IM-1247/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2829_IM-1247/2.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2829_IM-1247/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1158_IM-0107/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1158_IM-0107/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1020_IM-0017/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1020_IM-0017/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3093_IM-1446/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3093_IM-1446/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2322_IM-0894/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2322_IM-0894/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2321_IM-0894/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2321_IM-0894/2.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2321_IM-0894/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR470_IM-2099/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR470_IM-2099/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR910_IM-2416/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR910_IM-2416/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2317_IM-0890/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2317_IM-0890/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR197_IM-0631/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR197_IM-0631/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR298_IM-1369/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR298_IM-1369/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1030_IM-0024/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1030_IM-0024/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR628_IM-2208/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR628_IM-2208/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR492_IM-2112/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR492_IM-2112/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2216_IM-0821/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2216_IM-0821/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1619_IM-0400/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1619_IM-0400/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3242_IM-1534/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3242_IM-1534/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2290_IM-0874/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2290_IM-0874/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2217_IM-0822-0001/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2217_IM-0822-0001/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3036_IM-1409/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3036_IM-1409/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2112_IM-0742/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2112_IM-0742/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2597_IM-1087/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2597_IM-1087/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR564_IM-2165/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR564_IM-2165/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR707_IM-2270/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR707_IM-2270/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3745_IM-1872/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3745_IM-1872/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR722_IM-2282/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR722_IM-2282/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2415_IM-0961/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2415_IM-0961/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1960_IM-0627/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1960_IM-0627/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3928_IM-2000/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3928_IM-2000/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR250_IM-1025/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR250_IM-1025/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3080_IM-1440/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3080_IM-1440/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1204_IM-0138/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1204_IM-0138/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3735_IM-1866/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3735_IM-1866/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3203_IM-1513/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3203_IM-1513/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1688_IM-0450/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1688_IM-0450/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1587_IM-0381/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1587_IM-0381/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1308_IM-0201/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1308_IM-0201/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR558_IM-2158-0001/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR558_IM-2158-0001/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR399_IM-2043/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR399_IM-2043/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2690_IM-1162/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2690_IM-1162/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3685_IM-1836/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3685_IM-1836/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3045_IM-1418/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3045_IM-1418/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3230_IM-1527/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3230_IM-1527/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1698_IM-0458/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1698_IM-0458/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR383_IM-1932/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR383_IM-1932/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR259_IM-1083/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR259_IM-1083/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR812_IM-2343/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR812_IM-2343/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR499_IM-2116/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR499_IM-2116/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3094_IM-1447/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3094_IM-1447/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3974_IM-2034/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3974_IM-2034/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1524_IM-0339/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1524_IM-0339/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR256_IM-1064/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR256_IM-1064/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3166_IM-1491/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3166_IM-1491/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2963_IM-1356/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2963_IM-1356/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1961_IM-0628/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1961_IM-0628/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3176_IM-1497/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3176_IM-1497/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR651_IM-2229/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR651_IM-2229/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1231_IM-0155/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1231_IM-0155/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR80_IM-2333/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR80_IM-2333/2.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR80_IM-2333/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3905_IM-1984/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3905_IM-1984/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3634_IM-1801/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3634_IM-1801/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2197_IM-0807/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2197_IM-0807/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR297_IM-1361/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR297_IM-1361/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3380_IM-1628/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3380_IM-1628/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1272_IM-0183/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1272_IM-0183/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR744_IM-2299/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR744_IM-2299/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR251_IM-1032/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR251_IM-1032/2.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR251_IM-1032/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR245_IM-0985/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR245_IM-0985/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3984_IM-2040/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3984_IM-2040/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1889_IM-0577/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1889_IM-0577/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR944_IM-2440/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR944_IM-2440/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3501_IM-1706/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3501_IM-1706/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR181_IM-0524/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR181_IM-0524/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3366_IM-1618/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3366_IM-1618/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2879_IM-1284/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2879_IM-1284/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR34_IM-1644/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR34_IM-1644/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR865_IM-2385/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR865_IM-2385/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1180_IM-0123/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1180_IM-0123/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR714_IM-2276/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR714_IM-2276/2.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR714_IM-2276/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR353_IM-1726/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR353_IM-1726/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1529_IM-0342-0001/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1529_IM-0342-0001/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3794_IM-1908/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3794_IM-1908/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2852_IM-1261/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2852_IM-1261/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1687_IM-0450/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1687_IM-0450/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2590_IM-1083/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2590_IM-1083/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1263_IM-0179/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1263_IM-0179/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR934_IM-2432/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR934_IM-2432/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2851_IM-1260-0001/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2851_IM-1260-0001/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3663_IM-1822/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3663_IM-1822/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2016_IM-0665/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2016_IM-0665/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR182_IM-0531/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR182_IM-0531/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR674_IM-2247/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR674_IM-2247/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1048_IM-0036/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1048_IM-0036/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2492_IM-1018/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2492_IM-1018/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2554_IM-1059/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2554_IM-1059/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3616_IM-1789/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3616_IM-1789/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1055_IM-0040/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1055_IM-0040/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2639_IM-1124/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2639_IM-1124/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1552_IM-0360/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1552_IM-0360/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3916_IM-1991/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3916_IM-1991/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3937_IM-2008/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3937_IM-2008/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2839_IM-1252/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2839_IM-1252/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1121_IM-0080/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1121_IM-0080/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1710_IM-0469/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1710_IM-0469/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR606_IM-2195/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR606_IM-2195/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3113_IM-1462/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3113_IM-1462/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1217_IM-0145-0001/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1217_IM-0145-0001/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2662_IM-1143/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2662_IM-1143/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2866_IM-1273/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2866_IM-1273/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR809_IM-2342/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR809_IM-2342/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3096_IM-1448/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3096_IM-1448/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3997_IM-2048/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3997_IM-2048/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR836_IM-2360/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR836_IM-2360/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1517_IM-0335/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1517_IM-0335/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3655_IM-1817/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3655_IM-1817/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3187_IM-1503/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3187_IM-1503/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR849_IM-2371/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR849_IM-2371/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1354_IM-0230/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1354_IM-0230/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2031_IM-0676/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2031_IM-0676/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2098_IM-0728/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2098_IM-0728/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2047_IM-0688/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2047_IM-0688/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2181_IM-0793-1001/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2181_IM-0793-1001/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3266_IM-1551/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3266_IM-1551/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1879_IM-0569/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1879_IM-0569/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3465_IM-1683/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3465_IM-1683/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1902_IM-0586/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1902_IM-0586/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1075_IM-0054/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1075_IM-0054/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2334_IM-0902/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2334_IM-0902/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1835_IM-0539/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1835_IM-0539/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2785_IM-1220/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2785_IM-1220/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1058_IM-0041/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1058_IM-0041/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2225_IM-0829/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2225_IM-0829/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1891_IM-0580/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1891_IM-0580/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3128_IM-1471/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3128_IM-1471/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3739_IM-1868/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3739_IM-1868/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1396_IM-0252/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1396_IM-0252/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1229_IM-0152/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1229_IM-0152/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR630_IM-2211/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR630_IM-2211/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR154_IM-0350/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR154_IM-0350/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1723_IM-0477/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1723_IM-0477/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3464_IM-1683/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3464_IM-1683/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2768_IM-1212/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2768_IM-1212/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3763_IM-1883/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3763_IM-1883/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2439_IM-0978/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2439_IM-0978/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR477_IM-2101/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR477_IM-2101/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1453_IM-0292/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1453_IM-0292/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2519_IM-1037/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2519_IM-1037/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3354_IM-1609/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3354_IM-1609/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR810_IM-2343/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR810_IM-2343/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2102_IM-0733/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2102_IM-0733/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3543_IM-1735/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3543_IM-1735/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR943_IM-2439/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR943_IM-2439/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR726_IM-2286/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR726_IM-2286/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR681_IM-2252-0001/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR681_IM-2252-0001/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2704_IM-1171/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2704_IM-1171/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1678_IM-0447-0001/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1678_IM-0447-0001/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3602_IM-1778/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3602_IM-1778/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR718_IM-2280/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR718_IM-2280/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1813_IM-0526/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1813_IM-0526/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2670_IM-1148/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2670_IM-1148/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3317_IM-1587/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3317_IM-1587/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2902_IM-1306/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2902_IM-1306/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR49_IM-2110/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR49_IM-2110/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2888_IM-1290-0001/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2888_IM-1290-0001/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1271_IM-0182/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1271_IM-0182/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR969_IM-2459/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR969_IM-2459/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2739_IM-1193/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2739_IM-1193/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR195_IM-0618/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR195_IM-0618/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR881_IM-2396/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR881_IM-2396/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2537_IM-1049/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2537_IM-1049/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR150_IM-0325-0001/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR150_IM-0325-0001/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2695_IM-1166/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2695_IM-1166/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1699_IM-0459/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1699_IM-0459/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1388_IM-0246/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1388_IM-0246/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1211_IM-0142/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1211_IM-0142/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR428_IM-2070/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR428_IM-2070/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR349_IM-1697/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR349_IM-1697/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3305_IM-1581/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3305_IM-1581/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3524_IM-1721/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3524_IM-1721/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2152_IM-0772/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2152_IM-0772/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3993_IM-2044/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3993_IM-2044/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3534_IM-1727/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3534_IM-1727/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2118_IM-0745/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2118_IM-0745/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2030_IM-0675/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2030_IM-0675/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2668_IM-1147/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2668_IM-1147/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3090_IM-1445/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3090_IM-1445/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1469_IM-0303/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1469_IM-0303/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2920_IM-1323/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2920_IM-1323/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR992_IM-2477-0001/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR992_IM-2477-0001/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2939_IM-1339/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2939_IM-1339/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1514_IM-0333/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1514_IM-0333/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2734_IM-1189/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2734_IM-1189/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3851_IM-1948/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3851_IM-1948/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3946_IM-2015/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3946_IM-2015/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3385_IM-1632/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3385_IM-1632/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3832_IM-1935/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3832_IM-1935/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2401_IM-0950/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2401_IM-0950/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3774_IM-1892/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3774_IM-1892/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1061_IM-0043/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1061_IM-0043/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1163_IM-0108/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1163_IM-0108/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1745_IM-0489/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1745_IM-0489/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2238_IM-0835/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2238_IM-0835/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR932_IM-2430/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR932_IM-2430/2.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR932_IM-2430/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3245_IM-1537/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3245_IM-1537/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2127_IM-0751/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2127_IM-0751/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2871_IM-1277/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2871_IM-1277/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1314_IM-0204/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1314_IM-0204/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3866_IM-1959-0001/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3866_IM-1959-0001/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2176_IM-0789/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2176_IM-0789/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2818_IM-1242/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2818_IM-1242/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1145_IM-0097/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1145_IM-0097/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR993_IM-2478/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR993_IM-2478/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2595_IM-1086/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2595_IM-1086/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR696_IM-2261-1001/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR696_IM-2261-1001/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1580_IM-0378/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1580_IM-0378/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3675_IM-1829-0001/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3675_IM-1829-0001/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2365_IM-0927/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2365_IM-0927/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3962_IM-2027/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3962_IM-2027/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3120_IM-1466/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3120_IM-1466/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR129_IM-0189/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR129_IM-0189/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3922_IM-1996-0001/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3922_IM-1996-0001/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2113_IM-0742/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2113_IM-0742/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR999_IM-2480/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR999_IM-2480/2.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR999_IM-2480/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR354_IM-1731/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR354_IM-1731/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1197_IM-0131/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1197_IM-0131/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1359_IM-0233/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1359_IM-0233/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2416_IM-0961/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2416_IM-0961/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2_IM-0652/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2_IM-0652/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR961_IM-2452/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR961_IM-2452/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3502_IM-1707/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3502_IM-1707/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3883_IM-1971/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3883_IM-1971/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1669_IM-0441/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1669_IM-0441/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3253_IM-1542/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3253_IM-1542/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1898_IM-0581/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1898_IM-0581/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR725_IM-2285/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR725_IM-2285/2.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR725_IM-2285/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR680_IM-2251/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR680_IM-2251/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR212_IM-0746-1001/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR212_IM-0746-1001/2.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR212_IM-0746-1001/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2470_IM-1001/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2470_IM-1001/2.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2470_IM-1001/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR340_IM-1644/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR340_IM-1644/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3795_IM-1909/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3795_IM-1909/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR494_IM-2114/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR494_IM-2114/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR695_IM-2261/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR695_IM-2261/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3086_IM-1444/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3086_IM-1444/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3449_IM-1672/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3449_IM-1672/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR35_IM-1704/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR35_IM-1704/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1202_IM-0136/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1202_IM-0136/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1449_IM-0290/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1449_IM-0290/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3241_IM-1534/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3241_IM-1534/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2077_IM-0710/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2077_IM-0710/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1598_IM-0389/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1598_IM-0389/0.png
# ...
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2568_IM-1070/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2568_IM-1070/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR884_IM-2398/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR884_IM-2398/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3393_IM-1637/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3393_IM-1637/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR568_IM-2168/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR568_IM-2168/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1947_IM-0616/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1947_IM-0616/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1748_IM-0490/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1748_IM-0490/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3179_IM-1499/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3179_IM-1499/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2097_IM-0727-1001/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2097_IM-0727-1001/2.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2097_IM-0727-1001/3.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2097_IM-0727-1001/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2106_IM-0736/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2106_IM-0736/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR292_IM-1322/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR292_IM-1322/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1056_IM-0040/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1056_IM-0040/2.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1056_IM-0040/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3299_IM-1575/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3299_IM-1575/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3582_IM-1761/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3582_IM-1761/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2084_IM-0715-1001/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2084_IM-0715-1001/2.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2084_IM-0715-1001/3.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2084_IM-0715-1001/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3445_IM-1668/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3445_IM-1668/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2447_IM-0983/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2447_IM-0983/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3064_IM-1428/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3064_IM-1428/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3797_IM-1910-0001/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3797_IM-1910-0001/2.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3797_IM-1910-0001/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2544_IM-1054/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2544_IM-1054/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2614_IM-1105/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2614_IM-1105/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2969_IM-1360/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2969_IM-1360/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR595_IM-2187/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR595_IM-2187/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1369_IM-0238/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1369_IM-0238/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2065_IM-0701/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2065_IM-0701/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR837_IM-2361/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR837_IM-2361/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR503_IM-2121/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR503_IM-2121/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2840_IM-1253-1001/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2840_IM-1253-1001/2.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2840_IM-1253-1001/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR306_IM-1426/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR306_IM-1426/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR319_IM-1505/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR319_IM-1505/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3867_IM-1960/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3867_IM-1960/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR824_IM-2354/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR824_IM-2354/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR767_IM-2312/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR767_IM-2312/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3452_IM-1675/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3452_IM-1675/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR164_IM-0419/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR164_IM-0419/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR152_IM-0335/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR152_IM-0335/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR791_IM-2330/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR791_IM-2330/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3828_IM-1932/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3828_IM-1932/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3098_IM-1450/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3098_IM-1450/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3262_IM-1548/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3262_IM-1548/2.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3262_IM-1548/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3067_IM-1430/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3067_IM-1430/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2486_IM-1014/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2486_IM-1014/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR780_IM-2323/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR780_IM-2323/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1477_IM-0309/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1477_IM-0309/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1497_IM-0321/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1497_IM-0321/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR551_IM-2154/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR551_IM-2154/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1078_IM-0055/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1078_IM-0055/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3959_IM-2023/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3959_IM-2023/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3621_IM-1792/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3621_IM-1792/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2924_IM-1327/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2924_IM-1327/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2454_IM-0989/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2454_IM-0989/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3074_IM-1435/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3074_IM-1435/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1676_IM-0445/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1676_IM-0445/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2240_IM-0838/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2240_IM-0838/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR712_IM-2274-0001/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR712_IM-2274-0001/2.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR712_IM-2274-0001/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1823_IM-0534/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1823_IM-0534/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3525_IM-1722/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3525_IM-1722/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR585_IM-2181/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR585_IM-2181/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3143_IM-1477/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3143_IM-1477/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3264_IM-1550/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3264_IM-1550/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2053_IM-0691/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2053_IM-0691/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR521_IM-2132/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR521_IM-2132/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3456_IM-1678/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3456_IM-1678/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR191_IM-0591/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR191_IM-0591/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2020_IM-0668/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2020_IM-0668/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2808_IM-1238/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2808_IM-1238/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3522_IM-1720/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3522_IM-1720/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3486_IM-1695/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3486_IM-1695/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1139_IM-0095/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1139_IM-0095/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1918_IM-0597/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1918_IM-0597/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3508_IM-1710/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3508_IM-1710/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1685_IM-0449/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1685_IM-0449/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2173_IM-0786/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2173_IM-0786/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3131_IM-1473/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3131_IM-1473/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3382_IM-1629-0001/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3382_IM-1629-0001/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3208_IM-1515/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3208_IM-1515/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1276_IM-0184/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1276_IM-0184/2.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1276_IM-0184/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR27_IM-1168/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR27_IM-1168/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1593_IM-0385/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1593_IM-0385/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1894_IM-0581/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1894_IM-0581/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1190_IM-0128/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1190_IM-0128/2.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1190_IM-0128/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3346_IM-1604/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR3346_IM-1604/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1222_IM-0150/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR1222_IM-0150/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR768_IM-2313/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR768_IM-2313/0.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2171_IM-0786/1.png
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2171_IM-0786/0.png

# %% [markdown]
# # PneumoFusionNet V3
# ## Multimodal Chest X-ray Analysis using IU Dataset
#
# This project extends the previously developed GCSA-based chest X-ray classification model by introducing multimodal learning using radiology report text.
#
# Phase 1 focuses on image-only baseline evaluation using the IU Chest X-ray dataset.
#
# Phase 2 will integrate textual clinical reports using transformer-based NLP models.

# %% [markdown]
# #  Problem Statement
#
# Detect pneumonia using:
#
# - Chest X-ray images
# - Radiology reports
#
# ---
#
# Why multimodal?
#
# - Images capture visual patterns
# - Text provides clinical context
#
# ✅ Combining both improves performance

# %%
import os
import cv2
import torch
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from PIL import Image
import seaborn as sns

import torch.nn as nn
import torch.optim as optim

from torch.utils.data import Dataset, DataLoader

from torchvision import transforms
from torchvision import models
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    roc_auc_score
)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(device)
# Out:
# cuda

# %%
import json
import os

ANNOTATION_PATH = "/kaggle/input/datasets/abdelfettahelaanba/iu-dataset/annotation.json"

with open(ANNOTATION_PATH, 'r') as f:
    data = json.load(f)

# %%
type(data)
# Out:
# dict

# %%
len(data)
# Out:
# 3

# %%
list(data.keys())
# Out:
# ['train', 'val', 'test']

# %%
print(data.keys())
# Out:
# dict_keys(['train', 'val', 'test'])

# %%
print(data['train'][0])
# Out:
# {'id': 'CXR2384_IM-0942', 'report': 'The heart size and pulmonary vascularity appear within normal limits. A large hiatal hernia is noted. The lungs are free of focal airspace disease. No pneumothorax or pleural effusion is seen. Degenerative changes are present in the spine.', 'image_path': ['CXR2384_IM-0942/0.png', 'CXR2384_IM-0942/1.png'], 'split': 'train'}

# %% [markdown]
# # BUILD DATAFRAME

# %%
train_data = data['train']
val_data = data['val']
test_data = data['test']

# %%
def create_dataframe(split_data):

    records = []

    for item in split_data:

        records.append({
            'id': item['id'],
            'report': item['report'],
            'image_path': item['image_path'][0],
            'split': item['split']
        })

    return pd.DataFrame(records)

# %%
train_df = create_dataframe(train_data)

val_df = create_dataframe(val_data)

test_df = create_dataframe(test_data)

# %%
train_df.head()
# Out:
#                 id                                             report  \
# 0  CXR2384_IM-0942  The heart size and pulmonary vascularity appea...
# 1  CXR2926_IM-1328  Cardiac and mediastinal contours are within no...
# 2  CXR1451_IM-0291  Left lower lobe calcified granuloma. Heart siz...
# 3  CXR2887_IM-1289  The cardiomediastinal silhouette is normal in ...
# 4  CXR1647_IM-0424  The lungs are clear bilaterally. Specifically,...
#
#               image_path  split
# 0  CXR2384_IM-0942/0.png  train
# 1  CXR2926_IM-1328/0.png  train
# 2  CXR1451_IM-0291/0.png  train
# 3  CXR2887_IM-1289/0.png  train
# 4  CXR1647_IM-0424/0.png  train

# %%
IMAGE_DIR = "/kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images"

# %%
import os

sample_path = os.path.join(
    IMAGE_DIR,
    train_df.iloc[0]['image_path']
)

print(sample_path)
print(os.path.exists(sample_path))
# Out:
# /kaggle/input/datasets/abdelfettahelaanba/iu-dataset/images/images/CXR2384_IM-0942/0.png
# True

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open(sample_path)

plt.figure(figsize=(5,5))

plt.imshow(img, cmap='gray')

plt.axis('off')

plt.title("IU Dataset Sample")

plt.show()

# %%
DATA_DIR = "/kaggle/input/datasets/abdelfettahelaanba/iu-dataset"

IMAGE_DIR = os.path.join(
    DATA_DIR,
    "images/images"
)

ANNOTATION_PATH = os.path.join(
    DATA_DIR,
    "annotation.json"
)

SAVE_DIR = "/kaggle/working"

IMG_SIZE = 224
BATCH_SIZE = 16
NUM_EPOCHS = 10
LR = 1e-4

# %%
print("Train:", len(train_df))
print("Validation:", len(val_df))
print("Test:", len(test_df))
# Out:
# Train: 2069
# Validation: 296
# Test: 590

# %%
abnormal_keywords = [
    'opacity',
    'effusion',
    'pneumonia',
    'atelectasis',
    'edema',
    'mass',
    'nodule',
    'infiltrate',
    'consolidation'
]

# %%
def generate_label(report):

    report = report.lower()

    for word in abnormal_keywords:

        if word in report:
            return 1

    return 0

# %%
train_df['label'] = train_df['report'].apply(generate_label)

val_df['label'] = val_df['report'].apply(generate_label)

test_df['label'] = test_df['report'].apply(generate_label)

# %%
print(train_df['label'].value_counts())
# Out:
# label
# 1    1746
# 0     323
# Name: count, dtype: int64

# %%
transform = transforms.Compose([

    transforms.Resize((224,224)),

    transforms.RandomHorizontalFlip(),

    transforms.RandomRotation(10),

    transforms.ToTensor(),

    transforms.Normalize([0.449], [0.226])

])

# %%
class IUDataset(Dataset):

    def __init__(
        self,
        dataframe,
        image_dir,
        transform=None
    ):

        self.df = dataframe.reset_index(drop=True)

        self.image_dir = image_dir

        self.transform = transform

    def __len__(self):

        return len(self.df)

    def __getitem__(self, idx):

        row = self.df.iloc[idx]

        image_path = os.path.join(
            self.image_dir,
            row['image_path']
        )

        image = Image.open(image_path).convert('L')

        if self.transform:
            image = self.transform(image)

        label = torch.tensor(
            row['label'],
            dtype=torch.long
        )

        return image, label

# %%
train_dataset = IUDataset(
    train_df,
    IMAGE_DIR,
    transform
)

val_dataset = IUDataset(
    val_df,
    IMAGE_DIR,
    transform
)

test_dataset = IUDataset(
    test_df,
    IMAGE_DIR,
    transform
)

# %%
train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False
)

test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False
)

# %%
images, labels = next(iter(train_loader))

print(images.shape)

print(labels.shape)
# Out:
# torch.Size([16, 1, 224, 224])
# torch.Size([16])

# %% [markdown]
# # Model: PneumoFusionNet with 1-Channel ResNet50 + GCSA + DSC

# %%
def get_resnet50_1ch():
    model = models.resnet50(pretrained=True)

    # Replace first conv layer (3 → 1 channel)
    model.conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)

    # Initialize weights from pretrained
    with torch.no_grad():
        model.conv1.weight = nn.Parameter(
            model.conv1.weight.mean(dim=1, keepdim=True)
        )

    return model

# %%
class GCSA(nn.Module):
    def __init__(self, channels, reduction=16):
        super().__init__()

        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.max_pool = nn.AdaptiveMaxPool2d(1)\

        self.mlp = nn.Sequential(
            nn.Linear(channels, channels // reduction),
            nn.ReLU(),
            nn.Linear(channels // reduction, channels)
        )

        self.sigmoid = nn.Sigmoid()
        self.conv_spatial = nn.Conv2d(2, 1, kernel_size=7, padding=3)

    def forward(self, x):
        B, C, H, W = x.shape

        # Channel attention
        avg = self.avg_pool(x).view(B, C)
        max_ = self.max_pool(x).view(B, C)

        channel_att = self.sigmoid(self.mlp(avg) + self.mlp(max_)).view(B, C, 1, 1)
        x = x * channel_att

        # Spatial attention
        avg = torch.mean(x, dim=1, keepdim=True)
        max_, _ = torch.max(x, dim=1, keepdim=True)

        spatial = torch.cat([avg, max_], dim=1)
        spatial_att = self.sigmoid(self.conv_spatial(spatial))

        return x * spatial_att

# %%
class DepthwiseSeparableConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()

        self.depthwise = nn.Conv2d(
            in_channels, in_channels,
            kernel_size=3, padding=1,
            groups=in_channels, bias=False
        )

        self.pointwise = nn.Conv2d(
            in_channels, out_channels,
            kernel_size=1, bias=False
        )

        self.bn = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        x = self.depthwise(x)
        x = self.pointwise(x)
        return self.relu(self.bn(x))

# %%
class PneumoFusionNet(nn.Module):
    def __init__(self, num_classes=2):
        super().__init__()

        resnet = get_resnet50_1ch()

        # Remove FC layer
        self.backbone = nn.Sequential(*list(resnet.children())[:-2])

        # Add proposed improvements
        self.dsc = DepthwiseSeparableConv(2048, 1024)
        self.gcsa = GCSA(1024)

        self.pool = nn.AdaptiveAvgPool2d(1)

        self.fc = nn.Sequential(
         nn.Dropout(0.5),
         nn.Linear(1024, num_classes))
                            


    def forward(self, x):   # ✅ aligned properly
        x = self.backbone(x)      # ResNet output
        x = self.dsc(x)           # DSC
        x = self.gcsa(x)          # Attention
        x = self.pool(x)

        x = torch.flatten(x, 1)
        x = self.fc(x)

        return x

# %%
device = torch.device(
    "cuda" if torch.cuda.is_available() else "cpu"
)

model = PneumoFusionNet().to(device)

print(device)
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# cuda

# %%
IMG_SIZE = 224

BATCH_SIZE = 16

NUM_EPOCHS = 5

LR = 1e-4

WEIGHT_DECAY = 1e-5

# %%
criterion = nn.CrossEntropyLoss()

# %%
optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=LR,
    weight_decay=WEIGHT_DECAY
)

# %%
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='min',
    patience=2
)

# %%
def train_one_epoch(model, loader, criterion, optimizer, device):
    model.train()

    total_loss = 0
    correct = 0
    total = 0

    for images, labels in loader:
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = model(images)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        total_loss += loss.item()

        _, preds = torch.max(outputs, 1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    acc = 100 * correct / total

    return total_loss / len(loader), acc

# %%
def validate(model, loader, criterion, device):
    model.eval()

    total_loss = 0
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            total_loss += loss.item()

            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

    acc = 100 * correct / total

    return total_loss / len(loader), acc

# %%
best_val_acc = 0

train_losses = []
val_losses = []

train_accuracies = []
val_accuracies = []

# %%
OUTPUT_DIR = "/kaggle/working/outputs"
os.makedirs('results', exist_ok=True)
os.makedirs('results/gradcam', exist_ok=True)
os.makedirs('MODEL_DIR', exist_ok=True)
os.makedirs('PLOT_DIR', exist_ok=True)

print("Folders created successfully")
# Out:
# Folders created successfully

# %%
for epoch in range(NUM_EPOCHS):

    train_loss, train_acc = train_one_epoch(
        model,
        train_loader,
        criterion,
        optimizer,
        device
    )

    val_loss, val_acc = validate(
        model,
        val_loader,
        criterion,
        device
    )

    scheduler.step(val_loss)

    train_losses.append(train_loss)
    val_losses.append(val_loss)

    train_accuracies.append(train_acc)
    val_accuracies.append(val_acc)

    print(f"\nEpoch {epoch+1}/{NUM_EPOCHS}")

    print(f"Train Loss : {train_loss:.4f}")
    print(f"Train Acc  : {train_acc:.2f}%")

    print(f"Val Loss   : {val_loss:.4f}")
    print(f"Val Acc    : {val_acc:.2f}%")

    if val_acc > best_val_acc:

        best_val_acc = val_acc

        torch.save(
            model.state_dict(),
            "best_pneumofusion_v3.pth"
        )

        print("Best model saved!")
# Out:
# Epoch 1/5
# Train Loss : 0.4708
# Train Acc  : 83.66%
# Val Loss   : 0.3945
# Val Acc    : 86.15%
# Best model saved!
#
# Epoch 2/5
# Train Loss : 0.4345
# Train Acc  : 84.39%
# Val Loss   : 0.4034
# Val Acc    : 86.15%
#
# Epoch 3/5
# Train Loss : 0.4278
# Train Acc  : 84.39%
# Val Loss   : 0.4019
# Val Acc    : 86.15%
#
# Epoch 4/5
# Train Loss : 0.4292
# Train Acc  : 84.39%
# Val Loss   : 0.3872
# Val Acc    : 86.15%
#
# Epoch 5/5
# Train Loss : 0.4225
# Train Acc  : 84.34%
# Val Loss   : 0.3941
# Val Acc    : 86.15%

# %%
model.load_state_dict(
    torch.load("best_pneumofusion_v3.pth")
)

os.path.join(
    '/kaggle/working/MODEL_DIR',
    "best_pneumofusion_v3.pth"
)
# Out:
# '/kaggle/working/MODEL_DIR/best_pneumofusion_v3.pth'

# %%
test_loss, test_acc = validate(
    model,
    test_loader,
    criterion,
    device
)

print(f"Test Loss : {test_loss:.4f}")
print(f"Test Accuracy : {test_acc:.2f}%")
# Out:
# Test Loss : 0.4561
# Test Accuracy : 83.39%

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Loss Plot
axes[0].plot(train_losses, label='Train', linewidth=2)

axes[0].plot(val_losses, label='Val', linewidth=2)

axes[0].set_title('Loss')

axes[0].legend()

axes[0].grid(True)


# Accuracy Plot
axes[1].plot(train_accuracies, label='Train', linewidth=2)

axes[1].plot(val_accuracies, label='Val', linewidth=2)

axes[1].set_title('Accuracy')

axes[1].legend()

axes[1].grid(True)

plt.tight_layout()

plt.savefig(
    os.path.join(
        '/kaggle/working/MODEL_DIR',
        "training_curves.png"
    ),
    bbox_inches='tight'
)

plt.show()

# %%
all_preds, all_labels, all_probs = [], [], []

model.eval()

with torch.no_grad():

    for X, y in test_loader:

        X = X.to(device)

        y = y.to(device)

        out = model(X)

        probs = torch.softmax(out, dim=1)

        preds = torch.argmax(out, dim=1)

        all_preds.extend(preds.cpu().numpy())

        all_labels.extend(y.cpu().numpy())

        all_probs.extend(probs[:,1].cpu().numpy())
# ============================
# Metrics
# ============================
acc = accuracy_score(
    all_labels,
    all_preds
)
auc = roc_auc_score(
    all_labels,
    all_probs
)
print('=' * 55)
print(f'  Accuracy : {acc * 100:.2f}%')
print(f'  ROC-AUC  : {auc:.4f}')

# ============================
# Classification Report
# ============================
CLASSES = ['NORMAL', 'ABNORMAL']
report = classification_report(
    all_labels,
    all_preds,
    target_names=CLASSES
)

print(report)
with open('results/classification_report.txt','w'
) as f:
    f.write(report)
# Confusion Matrix
cm = confusion_matrix(all_labels,all_preds)
fig, ax = plt.subplots(figsize=(6,5))
sns.heatmap(cm,annot=True,fmt='d',cmap='Blues',xticklabels=CLASSES,yticklabels=CLASSES, linewidths=0.5,ax=ax)
ax.set_title(
    'Confusion Matrix — Test Set',
    fontweight='bold'
)
ax.set_ylabel('True')
ax.set_xlabel('Predicted')
plt.tight_layout()
# Save Confusion Matrix
fig.savefig(
    'results/confusion_matrix.png',
    dpi=300,
    bbox_inches='tight'
)
plt.show()
# ROC Curve
fpr, tpr, _ = roc_curve(
    all_labels,
    all_probs
)
fig, ax = plt.subplots(figsize=(6,5))

ax.plot(fpr,tpr,lw=2,color='steelblue',label=f'AUC = {auc:.4f}')
ax.plot([0,1],[0,1],'k--',lw=1)
ax.set_xlabel('FPR')
ax.set_ylabel('TPR')
ax.set_title(
    'ROC Curve — PneumoFusionNet',
    fontweight='bold'
)
ax.legend()
ax.grid(True, alpha=0.3)
plt.tight_layout()
# Save ROC Curve
fig.savefig(
    'results/roc_curve.png',
    dpi=300,
    bbox_inches='tight'
)
plt.show()
# Out:
# =======================================================
#   Accuracy : 83.39%
#   ROC-AUC  : 0.5597
#               precision    recall  f1-score   support
#
#       NORMAL       0.00      0.00      0.00        98
#     ABNORMAL       0.83      1.00      0.91       492
#
#     accuracy                           0.83       590
#    macro avg       0.42      0.50      0.45       590
# weighted avg       0.70      0.83      0.76       590
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# # Phase 1 Complete
#
# The GCSA-based image encoder from V2 was successfully adapted to the IU Chest X-ray dataset.
#
# Key challenges encountered:
# - weak supervision from reports
# - class imbalance
# - domain shift
# - noisy labels
#
# Weighted loss and improved label generation were introduced to stabilize training and improve generalization.
#
# This establishes the image-only baseline before multimodal image-text fusion.

# %% [markdown]
# # Phase 2: Multimodal Image-Text Fusion

# %%
from transformers import (
    BertTokenizer,
    BertModel
)

# %%
tokenizer = BertTokenizer.from_pretrained(
    'bert-base-uncased'
)

MAX_LEN = 128

# %%
class MultimodalDataset(Dataset):

    def __init__(
        self,
        dataframe,
        image_dir,
        tokenizer,
        max_len,
        transform=None
    ):

        self.df = dataframe.reset_index(drop=True)

        self.image_dir = image_dir

        self.tokenizer = tokenizer

        self.max_len = max_len

        self.transform = transform

    def __len__(self):

        return len(self.df)

    def __getitem__(self, idx):

        row = self.df.iloc[idx]

        # IMAGE
        image_path = os.path.join(
            self.image_dir,
            row['image_path']
        )

        image = Image.open(image_path).convert('L')

        if self.transform:
            image = self.transform(image)

        # TEXT
        report = row['report']

        encoding = self.tokenizer(

            report,

            add_special_tokens=True,

            max_length=self.max_len,

            padding='max_length',

            truncation=True,

            return_attention_mask=True,

            return_tensors='pt'
        )

        # LABEL
        label = torch.tensor(
            row['label'],
            dtype=torch.long
        )

        return {

            'image': image,

            'input_ids':
                encoding['input_ids'].flatten(),

            'attention_mask':
                encoding['attention_mask'].flatten(),

            'label': label
        }

# %%
train_dataset = MultimodalDataset(
    train_df,
    IMAGE_DIR,
    tokenizer,
    MAX_LEN,
    transform
)

val_dataset = MultimodalDataset(
    val_df,
    IMAGE_DIR,
    tokenizer,
    MAX_LEN,
    transform
)

test_dataset = MultimodalDataset(
    test_df,
    IMAGE_DIR,
    tokenizer,
    MAX_LEN,
    transform
)

# %%
train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False
)

test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False
)

# %%
batch = next(iter(train_loader))

print(batch['image'].shape)

print(batch['input_ids'].shape)

print(batch['attention_mask'].shape)

print(batch['label'].shape)
# Out:
# torch.Size([16, 1, 224, 224])
# torch.Size([16, 128])
# torch.Size([16, 128])
# torch.Size([16])

# %%
class TextEncoder(nn.Module):

    def __init__(self):

        super().__init__()

        self.bert = BertModel.from_pretrained(
            'bert-base-uncased'
        )

    def forward(
        self,
        input_ids,
        attention_mask
    ):

        outputs = self.bert(

            input_ids=input_ids,

            attention_mask=attention_mask
        )

        pooled_output = outputs.pooler_output

        return pooled_output

# %%
class MultimodalNet(nn.Module):

    def __init__(self):

        super().__init__()

        # IMAGE ENCODER
        self.image_encoder = PneumoFusionNet()

        # REMOVE OLD CLASSIFIER
        self.image_encoder.classifier = nn.Identity()

        # TEXT ENCODER
        self.text_encoder = TextEncoder()

        # IMAGE FEATURE PROJECTION
        self.image_projection = nn.Linear(
            2,
            256
        )

        # FUSION CLASSIFIER
        self.classifier = nn.Sequential(

            nn.Linear(256 + 768, 256),

            nn.ReLU(),

            nn.Dropout(0.3),

            nn.Linear(256, 2)
        )

    def forward(
        self,
        image,
        input_ids,
        attention_mask
    ):

        # IMAGE FEATURES
        image_features = self.image_encoder(image)

        image_features = self.image_projection(
            image_features
        )

        # TEXT FEATURES
        text_features = self.text_encoder(
            input_ids,
            attention_mask
        )

        # FUSION
        combined = torch.cat(
            [image_features, text_features],
            dim=1
        )

        # CLASSIFICATION
        output = self.classifier(combined)

        return output

# %%
model = MultimodalNet().to(device)

print("Multimodal model created successfully")
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Multimodal model created successfully

# %%
batch = next(iter(train_loader))

images = batch['image'].to(device)

input_ids = batch['input_ids'].to(device)

attention_mask = batch['attention_mask'].to(device)

outputs = model(
    images,
    input_ids,
    attention_mask
)

print(outputs.shape)
# Out:
# torch.Size([16, 2])

# %%
class_counts = train_df['label'].value_counts().sort_index()

weights = torch.tensor(
    [
        1.0 / class_counts[0],
        1.0 / class_counts[1]
    ],
    dtype=torch.float
).to(device)

criterion = nn.CrossEntropyLoss(
    weight=weights
)

# %%
optimizer = torch.optim.AdamW(

    model.parameters(),

    lr=2e-5,

    weight_decay=1e-5
)

# %%
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(

    optimizer,

    mode='min',

    patience=2
)

# %%
def train_one_epoch_multimodal(

    model,

    loader,

    criterion,

    optimizer,

    device
):

    model.train()

    running_loss = 0

    correct = 0

    total = 0

    for batch in loader:

        images = batch['image'].to(device)

        input_ids = batch['input_ids'].to(device)

        attention_mask = batch['attention_mask'].to(device)

        labels = batch['label'].to(device)

        optimizer.zero_grad()

        outputs = model(
            images,
            input_ids,
            attention_mask
        )

        loss = criterion(
            outputs,
            labels
        )

        loss.backward()

        optimizer.step()

        running_loss += loss.item()

        preds = torch.argmax(
            outputs,
            dim=1
        )

        correct += (
            preds == labels
        ).sum().item()

        total += labels.size(0)

    epoch_loss = running_loss / len(loader)

    epoch_acc = 100 * correct / total

    return epoch_loss, epoch_acc

# %%
def validate_multimodal(

    model,

    loader,

    criterion,

    device
):

    model.eval()

    running_loss = 0

    correct = 0

    total = 0

    with torch.no_grad():

        for batch in loader:

            images = batch['image'].to(device)

            input_ids = batch['input_ids'].to(device)

            attention_mask = batch['attention_mask'].to(device)

            labels = batch['label'].to(device)

            outputs = model(
                images,
                input_ids,
                attention_mask
            )

            loss = criterion(
                outputs,
                labels
            )

            running_loss += loss.item()

            preds = torch.argmax(
                outputs,
                dim=1
            )

            correct += (
                preds == labels
            ).sum().item()

            total += labels.size(0)

    epoch_loss = running_loss / len(loader)

    epoch_acc = 100 * correct / total

    return epoch_loss, epoch_acc

# %%
NUM_EPOCHS = 5

best_val_acc = 0

train_losses = []
val_losses = []

train_accuracies = []
val_accuracies = []

# %%
for epoch in range(NUM_EPOCHS):

    train_loss, train_acc = train_one_epoch_multimodal(

        model,

        train_loader,

        criterion,

        optimizer,

        device
    )

    val_loss, val_acc = validate_multimodal(

        model,

        val_loader,

        criterion,

        device
    )

    scheduler.step(val_loss)

    train_losses.append(train_loss)

    val_losses.append(val_loss)

    train_accuracies.append(train_acc)

    val_accuracies.append(val_acc)

    print(f"\nEpoch {epoch+1}/{NUM_EPOCHS}")

    print(f"Train Loss : {train_loss:.4f}")

    print(f"Train Acc  : {train_acc:.2f}%")

    print(f"Val Loss   : {val_loss:.4f}")

    print(f"Val Acc    : {val_acc:.2f}%")

    if val_acc > best_val_acc:

        best_val_acc = val_acc

        torch.save(

            model.state_dict(),

            os.path.join(
                '/kaggle/working/MODEL_DIR',
                "best_multimodal_model.pth"
            )
        )

        print("Best multimodal model saved!")
# Out:
# Epoch 1/5
# Train Loss : 0.3410
# Train Acc  : 90.43%
# Val Loss   : 0.1523
# Val Acc    : 95.27%
# Best multimodal model saved!
#
# Epoch 2/5
# Train Loss : 0.1000
# Train Acc  : 97.10%
# Val Loss   : 0.1743
# Val Acc    : 96.96%
# Best multimodal model saved!
#
# Epoch 3/5
# Train Loss : 0.0355
# Train Acc  : 99.13%
# Val Loss   : 0.0088
# Val Acc    : 99.66%
# Best multimodal model saved!
#
# Epoch 4/5
# Train Loss : 0.0273
# Train Acc  : 99.32%
# Val Loss   : 0.0136
# Val Acc    : 99.66%
#
# Epoch 5/5
# Train Loss : 0.0076
# Train Acc  : 99.90%
# Val Loss   : 0.0116
# Val Acc    : 99.66%

# %%
OUTPUT_DIR = "/kaggle/working/outputs"
os.makedirs('MultiModel_results', exist_ok=True)
os.makedirs('MultiModel_results/gradcam', exist_ok=True)
os.makedirs('MODEL_DIR', exist_ok=True)
os.makedirs('MultiModelPLOT_DIR', exist_ok=True)

print("Folders created successfully")
# Out:
# Folders created successfully

# %%
all_preds, all_labels, all_probs = [], [], []

model.eval()

with torch.no_grad():

    for batch in test_loader:

        images = batch['image'].to(device)

        input_ids = batch['input_ids'].to(device)

        attention_mask = batch['attention_mask'].to(device)

        labels = batch['label'].to(device)

        out = model(
            images,
            input_ids,
            attention_mask
        )

        probs = torch.softmax(out, dim=1)

        preds = torch.argmax(out, dim=1)

        all_preds.extend(preds.cpu().numpy())

        all_labels.extend(labels.cpu().numpy())

        all_probs.extend(probs[:,1].cpu().numpy())
# ============================
# Metrics
# ============================
acc = accuracy_score(
    all_labels,
    all_preds
)
auc = roc_auc_score(
    all_labels,
    all_probs
)
print('=' * 55)
print(f'  Accuracy : {acc * 100:.2f}%')
print(f'  ROC-AUC  : {auc:.4f}')

# ============================
# Classification Report
# ============================
CLASSES = ['NORMAL', 'ABNORMAL']
report = classification_report(
    all_labels,
    all_preds,
    target_names=CLASSES
)

print(report)
with open('MultiModel_results/classification_report.txt','w'
) as f:
    f.write(report)
# Confusion Matrix
cm = confusion_matrix(all_labels,all_preds)
fig, ax = plt.subplots(figsize=(6,5))
sns.heatmap(cm,annot=True,fmt='d',cmap='Blues',xticklabels=CLASSES,yticklabels=CLASSES, linewidths=0.5,ax=ax)
ax.set_title(
    'Multi_Confusion Matrix — Test Set',
    fontweight='bold'
)
ax.set_ylabel('True')
ax.set_xlabel('Predicted')
plt.tight_layout()
# Save Confusion Matrix
fig.savefig(
    'MultiModel_results/confusion_matrix.png',
    dpi=300,
    bbox_inches='tight'
)
plt.show()
# ROC Curve
fpr, tpr, _ = roc_curve(
    all_labels,
    all_probs
)
fig, ax = plt.subplots(figsize=(6,5))

ax.plot(fpr,tpr,lw=2,color='steelblue',label=f'AUC = {auc:.4f}')
ax.plot([0,1],[0,1],'k--',lw=1)
ax.set_xlabel('FPR')
ax.set_ylabel('TPR')
ax.set_title(
    'ROC Curve — Multi_PneumoFusionNet',
    fontweight='bold'
)
ax.legend()
ax.grid(True, alpha=0.3)
plt.tight_layout()
# Save ROC Curve
fig.savefig(
    'MultiModel_results/roc_curve.png',
    dpi=300,
    bbox_inches='tight'
)
plt.show()
# Out:
# =======================================================
#   Accuracy : 100.00%
#   ROC-AUC  : 1.0000
#               precision    recall  f1-score   support
#
#       NORMAL       1.00      1.00      1.00        98
#     ABNORMAL       1.00      1.00      1.00       492
#
#     accuracy                           1.00       590
#    macro avg       1.00      1.00      1.00       590
# weighted avg       1.00      1.00      1.00       590
